# %% [markdown]
# # Training Demo Notebook
# This notebook demonstrates training LR, NB, and SVM models using the project pipeline.
#
# It loads the dataset, performs preprocessing, and calls the unified training function.

# %%
import pandas as pd
from src.train import train_all

# Modify dataset path if necessary
dataset_path = 'data/sms_spam_no_header.csv'

print('Training models...')
train_all(dataset_path)
print('Training completed.')
